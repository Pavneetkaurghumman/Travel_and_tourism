# %% [markdown]
# <a href="https://colab.research.google.com/github/Pavneetkaurghumman/Travel_and_tourism/blob/main/Copy_of_Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"/content/drive/MyDrive/quick_commerce_data_raw (2).csv")

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   Order_ID                 1000000 non-null  int64
#  1   Company                  1000000 non-null  object
#  2   City                     948000 non-null   object
#  3   Customer_Age             1000000 non-null  int64
#  4   Order_Value              1000000 non-null  float64
#  5   Delivery_Time_Min        1000000 non-null  float64
#  6   Distance_Km              1000000 non-null  float64
#  7   Items_Count              965000 non-null   float64
#  8   Product_Category         1000000 non-null  object
#  9   Payment_Method           1000000 non-null  object
#  10  Customer_Rating          953000 non-null   float64
#  11  Discount_Applied         1000000 non-null  int64
#  12  Delivery_Partner_Rating  895863 non-null   float64
# dtypes: float64(6), int64(3), object(4)
# memory usage: 99.2+ MB
# (1000000, 13)

# %%
df.isnull().sum()
# Out:
# Order_ID                        0
# Company                         0
# City                        52000
# Customer_Age                    0
# Order_Value                     0
# Delivery_Time_Min               0
# Distance_Km                     0
# Items_Count                 35000
# Product_Category                0
# Payment_Method                  0
# Customer_Rating             47000
# Discount_Applied                0
# Delivery_Partner_Rating    104137
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df['Discount_Applied'] = df['Discount_Applied'].astype(int)

# %%
df['City'] = df['City'].str.strip().str.title()

# %%
df.describe()
# Out:
#            Order_ID    Customer_Age     Order_Value  Delivery_Time_Min  \
# count  1.000000e+06  1000000.000000  1000000.000000     1000000.000000
# mean   1.500000e+06       38.470387      571.643584          16.452412
# std    2.886753e+05       12.118520      382.784520           6.257172
# min    1.000001e+06       18.000000       50.000000           5.000000
# 25%    1.250001e+06       28.000000      287.840150          12.368000
# 50%    1.500000e+06       38.000000      531.324600          16.342000
# 75%    1.750000e+06       49.000000      796.182500          20.196000
# max    2.000000e+06       59.000000    13877.325000          40.000000
#
#           Distance_Km     Items_Count  Customer_Rating  Discount_Applied  \
# count  1000000.000000  1000000.000000   1000000.000000    1000000.000000
# mean         7.750231        9.999371         3.042573          0.400883
# std          4.186665        5.478659         1.186761          0.490078
# min          0.500000        1.000000         1.000000          0.000000
# 25%          4.130000        5.000000         2.000000          0.000000
# 50%          7.740000       10.000000         3.000000          0.000000
# 75%         11.380000       15.000000         4.000000          1.000000
# max         15.000000       19.000000         5.000000          1.000000
#
#        Delivery_Partner_Rating
# count            1000000.00000
# mean                   3.74853
# std                    0.72226
# min                    2.50000
# 25%                    3.10000
# 50%                    3.70000
# 75%                    4.40000
# max                    5.00000

# %%
df['Company'].value_counts()
df['Payment_Method'].value_counts()
# Out:
# Payment_Method
# Cash on Delivery    200739
# Debit Card          200038
# Credit Card         199884
# UPI                 199882
# Wallet              199457
# Name: count, dtype: int64

# %%
df.hist(figsize=(10,8))
# Out:
# array([[<Axes: title={'center': 'Order_ID'}>,
#         <Axes: title={'center': 'Customer_Age'}>,
#         <Axes: title={'center': 'Order_Value'}>],
#        [<Axes: title={'center': 'Delivery_Time_Min'}>,
#         <Axes: title={'center': 'Distance_Km'}>,
#         <Axes: title={'center': 'Items_Count'}>],
#        [<Axes: title={'center': 'Customer_Rating'}>,
#         <Axes: title={'center': 'Discount_Applied'}>,
#         <Axes: title={'center': 'Delivery_Partner_Rating'}>]],
#       dtype=object)

# %%
# Avg order value
df.groupby('Company')['Order_Value'].mean()
# Out:
# Company
# Amazon Now          557.568754
# Big Basket          576.105917
# Blinkit             610.486482
# Dunzo               541.062148
# Flipkart Minutes    563.661781
# Jio Mart            483.227569
# Swiggy Instamart    646.127917
# Zepto               594.518508
# Name: Order_Value, dtype: float64

# %%
# Orders per city
df['City'].value_counts()
# Out:
# City
# Hyderabad    83827
# Kolkata      83528
# Delhi        83520
# Amritsar     83457
# Gurgaon      83408
# Mumbai       83372
# Haridwar     83270
# Jaipur       83237
# Bengluru     83236
# Noida        83220
# Chennai      83096
# Pune         82829
# Name: count, dtype: int64

# %%
# Payment method
df['Payment_Method'].mode()
# Out:
# 0    Cash on Delivery
# Name: Payment_Method, dtype: object

# %%
# Avg delivery time
df['Delivery_Time_Min'].mean()
# Out:
# np.float64(16.452411642000005)

# %%
# Discount vs rating
df.groupby('Discount_Applied')['Customer_Rating'].mean()
# Out:
# Discount_Applied
# 0    3.043232
# 1    3.041588
# Name: Customer_Rating, dtype: float64

# %%
# Product category
df['Product_Category'].value_counts()
# Out:
# Product_Category
# Dairy                  143772
# Groceries              143202
# Household              142855
# Snacks                 142798
# Personal Care          142725
# Beverages              142610
# Fruits & Vegetables    142038
# Name: count, dtype: int64

# %%
# Distance vs time
df[['Distance_Km','Delivery_Time_Min']].corr()
# Out:
#                    Distance_Km  Delivery_Time_Min
# Distance_Km           1.000000           0.386376
# Delivery_Time_Min     0.386376           1.000000

# %%
# Best company
df.groupby('Company')['Customer_Rating'].mean()
# Out:
# Company
# Amazon Now          2.912955
# Big Basket          3.099230
# Blinkit             3.530672
# Dunzo               2.481066
# Flipkart Minutes    3.016538
# Jio Mart            2.827445
# Swiggy Instamart    3.274076
# Zepto               3.195669
# Name: Customer_Rating, dtype: float64

# %%
# Top 5 orders
df.nlargest(5, 'Order_Value')
# Out:
#         Order_ID           Company     City  Customer_Age  Order_Value  \
# 348927   1348928  Flipkart Minutes  Chennai            29  13877.32500
# 670358   1670359             Zepto  Kolkata            21  13405.62825
# 36263    1036264  Flipkart Minutes    Noida            31  13180.90500
# 317289   1317290  Swiggy Instamart  Gurgaon            41  12364.76175
# 998609   1998610        Big Basket     Pune            54  11466.34020
#
#         Delivery_Time_Min  Distance_Km  Items_Count     Product_Category  \
# 348927             17.070         8.45          1.0            Household
# 670358             11.378        10.63         19.0  Fruits & Vegetables
# 36263              14.584         2.64         13.0            Groceries
# 317289             17.848        13.08         10.0  Fruits & Vegetables
# 998609             14.936         1.56         19.0            Household
#
#           Payment_Method  Customer_Rating  Discount_Applied  \
# 348927               UPI              3.7                 1
# 670358  Cash on Delivery              1.6                 1
# 36263                UPI              2.7                 1
# 317289       Credit Card              3.8                 1
# 998609               UPI              3.9                 1
#
#         Delivery_Partner_Rating
# 348927                      2.5
# 670358                      4.9
# 36263                       3.9
# 317289                      4.3
# 998609                      4.6

# %%
# Age groups
df['Age_Group'] = pd.cut(df['Customer_Age'],
                        bins=[18,25,35,50,70],
                        labels=['18-25','26-35','36-50','50+'])
df.groupby('Age_Group')['Order_Value'].mean()
# Out:
# /tmp/ipykernel_6523/586967304.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Age_Group')['Order_Value'].mean()
# Age_Group
# 18-25    572.154254
# 26-35    571.138719
# 36-50    571.614590
# 50+      571.654786
# Name: Order_Value, dtype: float64

# %%
# Correlations
df.corr(numeric_only=True)
# Out:
#                          Order_ID  Customer_Age  Order_Value  \
# Order_ID                 1.000000      0.001084     0.000167
# Customer_Age             0.001084      1.000000     0.000112
# Order_Value              0.000167      0.000112     1.000000
# Delivery_Time_Min       -0.000906      0.000556    -0.120885
# Distance_Km             -0.001328      0.001863     0.000787
# Items_Count              0.000946     -0.001496    -0.001594
# Customer_Rating          0.001354     -0.002068     0.027357
# Discount_Applied        -0.000982      0.001905     0.302487
# Delivery_Partner_Rating  0.000820      0.002004    -0.000444
#
#                          Delivery_Time_Min  Distance_Km  Items_Count  \
# Order_ID                         -0.000906    -0.001328     0.000946
# Customer_Age                      0.000556     0.001863    -0.001496
# Order_Value                      -0.120885     0.000787    -0.001594
# Delivery_Time_Min                 1.000000     0.386376     0.000167
# Distance_Km                       0.386376     1.000000     0.001290
# Items_Count                       0.000167     0.001290     1.000000
# Customer_Rating                  -0.041509    -0.000376    -0.001108
# Discount_Applied                 -0.000232     0.000343     0.001523
# Delivery_Partner_Rating          -0.001223     0.001633     0.000713
#
#                          Customer_Rating  Discount_Applied  \
# Order_ID                        0.001354         -0.000982
# Customer_Age                   -0.002068          0.001905
# Order_Value                     0.027357          0.302487
# Delivery_Time_Min              -0.041509         -0.000232
# Distance_Km                    -0.000376          0.000343
# Items_Count                    -0.001108          0.001523
# Customer_Rating                 1.000000         -0.000679
# Discount_Applied               -0.000679          1.000000
# Delivery_Partner_Rating         0.001442         -0.001042
#
#                          Delivery_Partner_Rating
# Order_ID                                0.000820
# Customer_Age                            0.002004
# Order_Value                            -0.000444
# Delivery_Time_Min                      -0.001223
# Distance_Km                             0.001633
# Items_Count                             0.000713
# Customer_Rating                         0.001442
# Discount_Applied                       -0.001042
# Delivery_Partner_Rating                 1.000000

# %%
df['Company'].value_counts().plot(kind='bar')
plt.title("Orders per Company")
plt.show()

# %%
df['Payment_Method'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.show()

# %%
plt.plot(df['Distance_Km'], df['Delivery_Time_Min'], 'o')
plt.xlabel("Distance")
plt.ylabel("Delivery Time")
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()
